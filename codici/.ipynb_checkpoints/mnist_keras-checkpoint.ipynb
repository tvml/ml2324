# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pylab import subplot,imshow,title,gray,NullLocator
import scipy.misc as mi
import scipy.special as sp
from PIL import Image
from itertools import chain
from sklearn.metrics import confusion_matrix, accuracy_score


from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.models import model_from_json

from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.set_image_dim_ordering('th')

# %%
# visualizza dati
def displayData(X, t, rows=10, cols=10, img_ind=None, size =16, class_value = False):
    if len(X)>rows*cols:
        img_ind = np.random.permutation(len(X))[0:rows * cols]
    else:
        img_ind = range(rows*cols)
    fig = plt.figure(figsize = (size,size))
    fig.patch.set_facecolor('white')
    ax = fig.gca()
    for i in range(100):
        plt.subplot(10,10,i+1)
        plt.imshow([255-x for x in X[img_ind[i]]], cmap='gray', interpolation='gaussian')
        if class_value:
            plt.title("{}".format(t[img_ind[i]]),fontsize = 20)
        plt.gca().xaxis.set_major_locator(plt.NullLocator())
        plt.gca().yaxis.set_major_locator(plt.NullLocator())
        plt.axis('off')
    plt.subplots_adjust(top=1)
    plt.show()

# %%
def plotData(X, Y, c, npixel=28):
    m, n = X.shape
    image = np.array(X[c,:])
    plt.figure(figsize = (6,6))
    plt.imshow((image.reshape(npixel, npixel)), cmap='Greys', interpolation='quadric')
    plt.show()

# %%
def plotAccuracy(acc_history_train, acc_history_test):
    plt.figure(figsize = (12,8))
    plt.plot(acc_history_train, marker='o', markersize=5, label='Train')
    plt.plot(acc_history_test, marker='o', markersize=5, label='Test')
    plt.legend()
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.show()

# %%
def save_model(m,filename):
    model_json = m.to_json()
    with open(filename+".json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    m.save_weights(filename+".h5")
    print("Saved model to disk")

# %%
def load_model(filename):
    json_file = open(filename+'.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    m = model_from_json(loaded_model_json)
    # load weights into new model
    m.load_weights(filename+".h5")
    print("Loaded model from disk")
    return m

# %% [markdown]
# Fissa il numero di classi. Leggi i dati.

# %%
nb_classes = 10

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# Esempio di dati

# %%
displayData(X_train[0:100], y_train[0:100])

# %% [markdown]
# Esempio di dati con relativa classe

# %%
displayData(X_train[0:100], y_train[0:100], class_value=True)

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

# %% [markdown]
# Costruisci il modello (insieme delle possibili funzioni)

# %%
# softmax regression
model0 = Sequential()
model0.add(Dense(10, input_shape=(784,)))
model0.add(Activation('softmax'))
model0.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='sgd')

# %% [markdown]
# Cerca la migliore funzione possibile, rispetto ai dati disponibili

# %%
history0 = model0.fit(X_train, Y_train, batch_size=1024, epochs=20, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 2.0861 - acc: 0.3023 - val_loss: 1.8299 - val_acc: 0.5157
# Epoch 2/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.6575 - acc: 0.6187 - val_loss: 1.4880 - val_acc: 0.6917
# Epoch 3/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.3838 - acc: 0.7179 - val_loss: 1.2635 - val_acc: 0.7511
# Epoch 4/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.2008 - acc: 0.7597 - val_loss: 1.1101 - val_acc: 0.7841
# Epoch 5/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.0729 - acc: 0.7841 - val_loss: 1.0004 - val_acc: 0.8038
# Epoch 6/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.9795 - acc: 0.8006 - val_loss: 0.9186 - val_acc: 0.8167
# Epoch 7/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.9084 - acc: 0.8120 - val_loss: 0.8554 - val_acc: 0.8264
# Epoch 8/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.8525 - acc: 0.8209 - val_loss: 0.8049 - val_acc: 0.8370
# Epoch 9/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.8073 - acc: 0.8279 - val_loss: 0.7637 - val_acc: 0.8433
# Epoch 10/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.7700 - acc: 0.8339 - val_loss: 0.7295 - val_acc: 0.8489
# Epoch 11/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.7387 - acc: 0.8386 - val_loss: 0.7005 - val_acc: 0.8530
# Epoch 12/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.7119 - acc: 0.8425 - val_loss: 0.6756 - val_acc: 0.8562
# Epoch 13/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.6887 - acc: 0.8462 - val_loss: 0.6539 - val_acc: 0.8599
# Epoch 14/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6684 - acc: 0.8490 - val_loss: 0.6348 - val_acc: 0.8616
# Epoch 15/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6505 - acc: 0.8513 - val_loss: 0.6180 - val_acc: 0.8640
# Epoch 16/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.6346 - acc: 0.8541 - val_loss: 0.6029 - val_acc: 0.8657
# Epoch 17/20
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6203 - acc: 0.8562 - val_loss: 0.5894 - val_acc: 0.8673
# Epoch 18/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.6073 - acc: 0.8582 - val_loss: 0.5771 - val_acc: 0.8688
# Epoch 19/20
# 60000/60000 [==============================] - 0s 7us/step - loss: 0.5956 - acc: 0.8594 - val_loss: 0.5659 - val_acc: 0.8704
# Epoch 20/20
# 60000/60000 [==============================] - 1s 8us/step - loss: 0.5849 - acc: 0.8613 - val_loss: 0.5557 - val_acc: 0.8722

# %% [markdown]
# Accuracy: frazione di risposte corrette

# %%
acc_values0 = history0.history['acc']
val_acc_values0 = history0.history['val_acc']

# %%
plotAccuracy(acc_values0, val_acc_values0)

# %%
predictions_train = model0.predict_classes(X_train, verbose=0)

# %%
confusion_matrix(y_train, predictions_train)
# Out:
# array([[5604,    1,   32,   30,   16,   43,  105,   13,   62,   17],
#        [   0, 6419,   30,   24,    2,   41,   10,    9,  197,   10],
#        [  82,  143, 4887,  116,  126,   10,  206,  119,  216,   53],
#        [  60,   67,  178, 5121,   10,  226,   65,  105,  211,   88],
#        [  16,   54,   39,    6, 5118,   15,   88,   16,   76,  414],
#        [ 130,  150,   59,  387,  141, 4008,  154,   35,  244,  113],
#        [  66,   77,   98,    5,   49,  114, 5452,    3,   53,    1],
#        [  73,  179,   92,   20,  108,    9,   10, 5487,   34,  253],
#        [  41,  230,   88,  288,   48,  200,   52,   37, 4689,  178],
#        [  62,   79,   68,  111,  293,   45,    7,  284,   67, 4933]])

# %%
accuracy_score(y_train, predictions_train)
# Out:
# 0.8619666666666667

# %%
predictions_test = model0.predict_classes(X_test, verbose=0)

# %%
confusion_matrix(y_test, predictions_test)
# Out:
# array([[ 942,    0,    4,    1,    0,    6,   17,    1,    9,    0],
#        [   0, 1087,    4,    4,    1,    2,    4,    1,   32,    0],
#        [  19,   20,  844,   23,   16,    0,   31,   21,   49,    9],
#        [   5,    2,   24,  872,    1,   35,   11,   20,   29,   11],
#        [   2,    9,    4,    0,  875,    1,   13,    2,   10,   66],
#        [  21,   14,    5,   58,   27,  674,   28,   12,   41,   12],
#        [  17,    4,   16,    4,   13,   18,  874,    0,   12,    0],
#        [   4,   36,   27,    0,   13,    0,    4,  898,    6,   40],
#        [   8,   13,   13,   35,   13,   24,   17,   12,  815,   24],
#        [  15,   10,   14,   14,   55,   11,    1,   39,    9,  841]])

# %%
accuracy_score(y_test, predictions_test)
# Out:
# 0.8722

# %%
w = model0.layers[0].get_weights()[0]

# %%
fig = plt.figure(figsize=(16,16))
fig.patch.set_facecolor('white')
for i in range(10):
    ax = subplot(2,5,i+1,frame_on=False, facecolor="#F8F8F8")
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())
    imshow(w[:,i].reshape(28,28), interpolation='quadric', 
           cmap=plt.get_cmap('Greys'), vmin=np.mean(w[:,i])-3.5*np.std(w[:,i]), 
           vmax=np.mean(w[:,i])+3.5*np.std(w[:,i]), aspect='auto')
    plt.title(i)
plt.subplots_adjust(top=0.4)
plt.show()

# %%
c = np.random.randint(0, X_test.shape[0])
p=model0.predict_classes(X_test[c:c+1,:], verbose=0)
print("Elemento "+str(c))
plotData(X_test, y_test, c)
print("Un "+str(y_test[c])+", classificato come " + str(p[0]))
# Out:
# Elemento 7535
# Un 9, classificato come 9

# %%
# 3 layer NN
model1 = Sequential()
model1.add(Dense(512, input_shape=(784,)))
model1.add(Activation('relu'))
model1.add(Dropout(0.2))
model1.add(Dense(10))
model1.add(Activation('softmax'))
model1.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
history1 = model1.fit(X_train, Y_train, batch_size=1024, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.5768 - acc: 0.8404 - val_loss: 0.2598 - val_acc: 0.9250
# Epoch 2/10
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.2395 - acc: 0.9327 - val_loss: 0.1894 - val_acc: 0.9449
# Epoch 3/10
# 60000/60000 [==============================] - 4s 58us/step - loss: 0.1822 - acc: 0.9481 - val_loss: 0.1504 - val_acc: 0.9573
# Epoch 4/10
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1460 - acc: 0.9586 - val_loss: 0.1280 - val_acc: 0.9630
# Epoch 5/10
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1219 - acc: 0.9655 - val_loss: 0.1111 - val_acc: 0.9679
# Epoch 6/10
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1041 - acc: 0.9710 - val_loss: 0.0984 - val_acc: 0.9697
# Epoch 7/10
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0903 - acc: 0.9744 - val_loss: 0.0908 - val_acc: 0.9727
# Epoch 8/10
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.0800 - acc: 0.9768 - val_loss: 0.0837 - val_acc: 0.9753
# Epoch 9/10
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0709 - acc: 0.9797 - val_loss: 0.0797 - val_acc: 0.9753
# Epoch 10/10
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.0626 - acc: 0.9821 - val_loss: 0.0730 - val_acc: 0.9786

# %%
acc_values1 = history1.history['acc']
val_acc_values1 = history1.history['val_acc']

epochs1 = range(1, len(acc_values1) + 1)

# %%
plotAccuracy(acc_values1, val_acc_values1)

# %%
predictions_train = model1.predict_classes(X_train, verbose=0)

# %%
confusion_matrix(y_train, predictions_train)
# Out:
# array([[5881,    1,    0,    1,    0,    4,   12,    1,   13,   10],
#        [   1, 6690,    9,    3,    8,    0,    4,   12,    8,    7],
#        [   9,    5, 5875,    7,   10,    3,    4,   21,   19,    5],
#        [   2,    4,   18, 5994,    1,   30,    1,   21,   36,   24],
#        [   2,    8,    3,    0, 5767,    1,   10,    4,    3,   44],
#        [   6,    3,    4,   20,    4, 5352,   13,    1,    7,   11],
#        [  10,    4,    0,    0,    7,   12, 5878,    0,    7,    0],
#        [   2,   14,   12,    0,   10,    1,    0, 6198,    5,   23],
#        [   5,   25,    3,   11,    5,    9,   10,    6, 5761,   16],
#        [   7,    4,    0,    8,   20,    9,    1,   21,    8, 5871]])

# %%
accuracy_score(y_train, predictions_train)
# Out:
# 0.9877833333333333

# %%
predictions_test = model1.predict_classes(X_test, verbose=0)

# %%
confusion_matrix(y_test, predictions_test)
# Out:
# array([[ 971,    0,    1,    1,    0,    2,    3,    1,    1,    0],
#        [   0, 1123,    4,    0,    0,    0,    3,    0,    5,    0],
#        [   4,    1, 1004,    1,    4,    0,    2,    7,    8,    1],
#        [   0,    0,    3,  986,    0,    5,    0,    8,    5,    3],
#        [   1,    0,    2,    1,  960,    0,    4,    2,    1,   11],
#        [   2,    0,    0,    4,    2,  872,    6,    1,    3,    2],
#        [   4,    3,    0,    1,    3,    4,  939,    0,    4,    0],
#        [   0,    6,    9,    1,    0,    1,    0, 1003,    2,    6],
#        [   4,    0,    1,    3,    3,    3,    3,    4,  948,    5],
#        [   4,    4,    0,    4,    9,    1,    0,    6,    1,  980]])

# %%
accuracy_score(y_test, predictions_test)
# Out:
# 0.9786

# %%
w0 = model1.layers[0].get_weights()[0]
w1 = model1.layers[3].get_weights()[0]
w = np.dot(w0,w1)

# %%
fig = plt.figure(figsize=(16,16))
fig.patch.set_facecolor('white')
for i in range(10):
    ax = subplot(2,5,i+1,frame_on=False, facecolor="#F8F8F8")
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())
    imshow(w[:,i].reshape(28,28), interpolation='quadric', 
           cmap=plt.get_cmap('Greys'), vmin=np.mean(w[:,i])-3.5*np.std(w[:,i]), 
           vmax=np.mean(w[:,i])+3.5*np.std(w[:,i]), aspect='auto')
    plt.title(i)
plt.subplots_adjust(top=0.4)
plt.show()

# %%
# 4 layer NN
model2 = Sequential()
model2.add(Dense(512, input_shape=(784,)))
model2.add(Activation('relu'))
model2.add(Dropout(0.2))
model2.add(Dense(512))
model2.add(Activation('relu'))
model2.add(Dropout(0.2))
model2.add(Dense(10))
model2.add(Activation('softmax'))

# %%
model2.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
history2 = model2.fit(X_train, Y_train, batch_size=1024, epochs=10, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.4909 - acc: 0.8601 - val_loss: 0.1827 - val_acc: 0.9454
# Epoch 2/10
# 60000/60000 [==============================] - 6s 102us/step - loss: 0.1740 - acc: 0.9490 - val_loss: 0.1212 - val_acc: 0.9643
# Epoch 3/10
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.1195 - acc: 0.9649 - val_loss: 0.0969 - val_acc: 0.9694
# Epoch 4/10
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.0891 - acc: 0.9736 - val_loss: 0.0812 - val_acc: 0.9737
# Epoch 5/10
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.0726 - acc: 0.9779 - val_loss: 0.0739 - val_acc: 0.9765
# Epoch 6/10
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.0576 - acc: 0.9823 - val_loss: 0.0672 - val_acc: 0.9788
# Epoch 7/10
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0494 - acc: 0.9848 - val_loss: 0.0636 - val_acc: 0.9797
# Epoch 8/10
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0410 - acc: 0.9875 - val_loss: 0.0698 - val_acc: 0.9792
# Epoch 9/10
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0354 - acc: 0.9890 - val_loss: 0.0628 - val_acc: 0.9803
# Epoch 10/10
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0294 - acc: 0.9906 - val_loss: 0.0557 - val_acc: 0.9827

# %%
acc_values2 = history2.history['acc']
val_acc_values2 = history2.history['val_acc']

epochs2 = range(1, len(acc_values2) + 1)

# %%
plotAccuracy(acc_values2, val_acc_values2)

# %%
predictions_train = model2.predict_classes(X_train, verbose=0)

# %%
confusion_matrix(y_train, predictions_train)
# Out:
# array([[5917,    0,    0,    0,    0,    0,    2,    0,    3,    1],
#        [   0, 6722,    3,    1,    5,    0,    0,    9,    1,    1],
#        [   3,    1, 5942,    1,    1,    0,    1,    6,    2,    1],
#        [   0,    2,    8, 6084,    0,   10,    0,   12,    5,   10],
#        [   0,    1,    0,    0, 5834,    0,    0,    1,    0,    6],
#        [   0,    0,    1,    5,    0, 5403,    8,    0,    3,    1],
#        [   2,    2,    0,    0,    2,    3, 5907,    0,    2,    0],
#        [   1,    3,    3,    0,    0,    0,    0, 6255,    0,    3],
#        [   3,   11,    4,    1,    0,    1,    2,    1, 5821,    7],
#        [   0,    1,    0,    0,    4,    1,    0,    7,    1, 5935]])

# %%
accuracy_score(y_train, predictions_train)
# Out:
# 0.997

# %%
predictions_test = model2.predict_classes(X_test, verbose=0)

# %%
confusion_matrix(y_test, predictions_test)
# Out:
# array([[ 972,    1,    0,    0,    1,    0,    2,    1,    2,    1],
#        [   0, 1127,    3,    0,    0,    1,    2,    0,    2,    0],
#        [   3,    0, 1015,    0,    2,    0,    2,    5,    4,    1],
#        [   0,    0,    6,  986,    0,    3,    0,    7,    2,    6],
#        [   1,    0,    2,    0,  965,    0,    3,    1,    0,   10],
#        [   2,    0,    0,    4,    1,  873,    4,    0,    5,    3],
#        [   4,    3,    0,    1,    4,    2,  944,    0,    0,    0],
#        [   1,    2,    6,    0,    1,    0,    0, 1014,    1,    3],
#        [   4,    1,    3,    3,    3,    5,    1,    6,  943,    5],
#        [   2,    2,    0,    3,    7,    1,    1,    5,    0,  988]])

# %%
accuracy_score(y_test, predictions_test)
# Out:
# 0.9827

# %%
w0 = model2.layers[0].get_weights()[0]
w1 = model2.layers[3].get_weights()[0]
w2 = model2.layers[6].get_weights()[0]
w = np.dot(np.dot(w0,w1),w2)

# %%
fig = plt.figure(figsize=(16,16))
fig.patch.set_facecolor('white')
for i in range(10):
    ax = subplot(2,5,i+1,frame_on=False, facecolor="#F8F8F8")
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())
    imshow(w[:,i].reshape(28,28), interpolation='quadric', 
           cmap=plt.get_cmap('Greys'), vmin=np.mean(w[:,i])-3.5*np.std(w[:,i]), 
           vmax=np.mean(w[:,i])+3.5*np.std(w[:,i]), aspect='auto')
    plt.title(i)
plt.subplots_adjust(top=0.4)
plt.show()

# %%
model3 = Sequential()
model3.add(Conv2D(30, (5, 5), input_shape=(1, 28, 28), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Conv2D(15, (3, 3), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.2))
model3.add(Flatten())
model3.add(Dense(128, activation='relu'))
model3.add(Dense(50, activation='relu'))
model3.add(Dense(10, activation='softmax'))

# %%
model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
X_train_c = X_train.reshape(X_train.shape[0], 1, 28, 28).astype('float32')
X_test_c = X_test.reshape(X_test.shape[0], 1, 28, 28).astype('float32')

# %%
history3 = model3.fit(X_train_c, Y_train, batch_size=1024, epochs=10, verbose=1, validation_data=(X_test_c, Y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 47s 785us/step - loss: 1.0591 - acc: 0.6692 - val_loss: 0.2302 - val_acc: 0.9359
# Epoch 2/10
# 60000/60000 [==============================] - 47s 777us/step - loss: 0.2093 - acc: 0.9365 - val_loss: 0.1081 - val_acc: 0.9674
# Epoch 3/10
# 60000/60000 [==============================] - 47s 784us/step - loss: 0.1307 - acc: 0.9605 - val_loss: 0.0774 - val_acc: 0.9754
# Epoch 4/10
# 60000/60000 [==============================] - 46s 762us/step - loss: 0.1000 - acc: 0.9696 - val_loss: 0.0605 - val_acc: 0.9806
# Epoch 5/10
# 60000/60000 [==============================] - 46s 766us/step - loss: 0.0836 - acc: 0.9742 - val_loss: 0.0494 - val_acc: 0.9851
# Epoch 6/10
# 60000/60000 [==============================] - 43s 724us/step - loss: 0.0714 - acc: 0.9777 - val_loss: 0.0466 - val_acc: 0.9845
# Epoch 7/10
# 60000/60000 [==============================] - 41s 689us/step - loss: 0.0636 - acc: 0.9800 - val_loss: 0.0401 - val_acc: 0.9872
# Epoch 8/10
# 60000/60000 [==============================] - 42s 698us/step - loss: 0.0594 - acc: 0.9816 - val_loss: 0.0367 - val_acc: 0.9879
# Epoch 9/10
# 60000/60000 [==============================] - 48s 799us/step - loss: 0.0528 - acc: 0.9839 - val_loss: 0.0370 - val_acc: 0.9883
# Epoch 10/10
# 60000/60000 [==============================] - 58s 969us/step - loss: 0.0501 - acc: 0.9843 - val_loss: 0.0330 - val_acc: 0.9898

# %%
acc_values3 = history3.history['acc']
val_acc_values3 = history3.history['val_acc']

epochs3 = range(1, len(acc_values3) + 1)

# %%
plotAccuracy(acc_values3, val_acc_values3)

# %%
predictions_train = model3.predict_classes(X_train_c, verbose=0)

# %%
confusion_matrix(y_train, predictions_train)
# Out:
# array([[5896,    1,    3,    0,    0,    2,    8,    0,   10,    3],
#        [   0, 6691,    8,    3,    9,    0,    4,   13,   14,    0],
#        [   1,    6, 5905,    9,    2,    0,    1,   18,    9,    7],
#        [   2,    0,   14, 6043,    0,   24,    0,   17,   17,   14],
#        [   1,    4,    2,    0, 5810,    0,    4,    2,    4,   15],
#        [   2,    1,    1,    9,    1, 5372,   15,    0,   16,    4],
#        [   4,    1,    2,    1,    7,    8, 5887,    0,    8,    0],
#        [   0,    6,   12,    1,    9,    1,    0, 6217,    8,   11],
#        [   3,    9,    7,    6,   10,   20,    2,    4, 5778,   12],
#        [   8,    4,    0,   10,   43,   12,    1,   21,   23, 5827]])

# %%
accuracy_score(y_train, predictions_train)
# Out:
# 0.9904333333333334

# %%
predictions_test = model3.predict_classes(X_test, verbose=0)

# %%
confusion_matrix(y_test, predictions_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 7s 118us/step - loss: 0.5988 - acc: 0.8342 - val_loss: 0.2581 - val_acc: 0.9267
# Epoch 2/30
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.2404 - acc: 0.9335 - val_loss: 0.1884 - val_acc: 0.9469
# Epoch 3/30
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.1823 - acc: 0.9488 - val_loss: 0.1505 - val_acc: 0.9574
# Epoch 4/30
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1467 - acc: 0.9587 - val_loss: 0.1265 - val_acc: 0.9630
# Epoch 5/30
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1226 - acc: 0.9650 - val_loss: 0.1107 - val_acc: 0.9669
# Epoch 6/30
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.1047 - acc: 0.9704 - val_loss: 0.1022 - val_acc: 0.9699
# Epoch 7/30
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.0930 - acc: 0.9741 - val_loss: 0.0907 - val_acc: 0.9725
# Epoch 8/30
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.0808 - acc: 0.9775 - val_loss: 0.0838 - val_acc: 0.9746
# Epoch 9/30
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0719 - acc: 0.9800 - val_loss: 0.0774 - val_acc: 0.9760
# Epoch 10/30
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0643 - acc: 0.9819 - val_loss: 0.0736 - val_acc: 0.9777
# Epoch 11/30
# 60000/60000 [==============================] - 16s 260us/step - loss: 0.0582 - acc: 0.9835 - val_loss: 0.0726 - val_acc: 0.9777
# Epoch 12/30
# 60000/60000 [==============================] - 10s 164us/step - loss: 0.0528 - acc: 0.9856 - val_loss: 0.0694 - val_acc: 0.9780
# Epoch 13/30
# 60000/60000 [==============================] - 8s 141us/step - loss: 0.0481 - acc: 0.9864 - val_loss: 0.0653 - val_acc: 0.9794
# Epoch 14/30
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0438 - acc: 0.9880 - val_loss: 0.0651 - val_acc: 0.9796
# Epoch 15/30
# 60000/60000 [==============================] - 8s 134us/step - loss: 0.0398 - acc: 0.9891 - val_loss: 0.0617 - val_acc: 0.9801
# Epoch 16/30
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0360 - acc: 0.9903 - val_loss: 0.0620 - val_acc: 0.9801
# Epoch 17/30
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0333 - acc: 0.9913 - val_loss: 0.0603 - val_acc: 0.9815
# Epoch 18/30
# 60000/60000 [==============================] - 8s 127us/step - loss: 0.0310 - acc: 0.9918 - val_loss: 0.0614 - val_acc: 0.9809
# Epoch 19/30
# 60000/60000 [==============================] - 7s 110us/step - loss: 0.0287 - acc: 0.9923 - val_loss: 0.0582 - val_acc: 0.9808
# Epoch 20/30
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0260 - acc: 0.9933 - val_loss: 0.0579 - val_acc: 0.9813
# Epoch 21/30
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.0246 - acc: 0.9939 - val_loss: 0.0565 - val_acc: 0.9817
# Epoch 22/30
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.0220 - acc: 0.9947 - val_loss: 0.0568 - val_acc: 0.9823
# Epoch 23/30
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.0206 - acc: 0.9949 - val_loss: 0.0572 - val_acc: 0.9810
# Epoch 24/30
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0189 - acc: 0.9955 - val_loss: 0.0569 - val_acc: 0.9828
# Epoch 25/30
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0180 - acc: 0.9959 - val_loss: 0.0553 - val_acc: 0.9823
# Epoch 26/30
# 60000/60000 [==============================] - 7s 118us/step - loss: 0.0161 - acc: 0.9963 - val_loss: 0.0545 - val_acc: 0.9820
# Epoch 27/30
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0150 - acc: 0.9967 - val_loss: 0.0554 - val_acc: 0.9819
# Epoch 28/30
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0147 - acc: 0.9967 - val_loss: 0.0574 - val_acc: 0.9814
# Epoch 29/30
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.0135 - acc: 0.9972 - val_loss: 0.0560 - val_acc: 0.9816
# Epoch 30/30
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0130 - acc: 0.9971 - val_loss: 0.0568 - val_acc: 0.9821

# %%
accuracy_score(y_test, predictions_test)
